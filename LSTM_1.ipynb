# %% [markdown]
# # Import Libraries

# %%
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import numpy as np
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import glob
from datetime import datetime
from keras.layers import Dropout
import numpy  as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### https://machinelearningmastery.com/gentle-introduction-long-short-term-memory-networks-experts/

# %% [markdown]
# # Load the Data

# %% [markdown]
# ### The Data is loaded in one DataFrame and the columns with weather data, radiation and AC power are considered.

# %%
def load_data(path):
    xl = pd.ExcelFile('Data_example.xlsx')
    xl.sheet_names
    listdf=[]
    for i in xl.sheet_names:
        data=pd.read_excel(path,header=1,sheet_name=i, infer_datetime_format=True, index_col="Unnamed: 0" ).iloc[:,:11] 
        listdf.append(data)
    dffinal=pd.concat(listdf)
    dffinal = dffinal.astype('float32') 
    return dffinal

# %% [markdown]
# ### Filling the missing values in the timeseries with interpolation and saving in a new csv file

# %%
def fill_miss(data):
    dtr =pd.DataFrame( pd.date_range(start="2018-12-01", end="2019-07-01", freq="15T")[1:]).set_index(0)
    #inner merge to eliminate the same mesurment
    dfouter=dtr.join(data,how="outer")
    dfouter.interpolate(inplace=True)
    dfouter.to_excel('Data_examplemod.xlsx')
    return dfouter

# %% [markdown]
# ### Runing the functions

# %%
path='Data_example.xlsx'
data=load_data(path)
data=fill_miss(data)

# %% [markdown]
# ## Loading the DataFrame and resample

# %%
data=pd.read_excel('Data_examplemod.xlsx',infer_datetime_format=True, index_col="Unnamed: 0")

# %% [markdown]
# ### Resample 1hr

# %%
data=data.resample('1H').mean()
display(data.head(3), data.shape)
# Out:
#                      Wind Direction (Mean) [°]  \
# 2018-12-01 00:00:00                 157.136668
# 2018-12-01 01:00:00                 145.937496
# 2018-12-01 02:00:00                 147.695000
#
#                      Wind Speed [m/s] (Mean) [m/s]   Total rain (Mean) [mm]  \
# 2018-12-01 00:00:00                          1.7000             1793.233317
# 2018-12-01 01:00:00                          2.0025             1793.404999
# 2018-12-01 02:00:00                          1.8550             1793.630005
#
#                      Current Rain (Mean) [mm]   Humidity (Mean) [%]  \
# 2018-12-01 00:00:00                  0.003333             78.713333
# 2018-12-01 01:00:00                  0.005000             84.445000
# 2018-12-01 02:00:00                  0.000000             86.740000
#
#                      Temperature (Mean) [°C]  \
# 2018-12-01 00:00:00                 0.283333
# 2018-12-01 01:00:00                 0.047500
# 2018-12-01 02:00:00                 0.130000
#
#                      Atmospheric Pressure (Mean) [hPa]  \
# 2018-12-01 00:00:00                        1008.203328
# 2018-12-01 01:00:00                        1007.825012
# 2018-12-01 02:00:00                        1007.744995
#
#                      Temperature: Ambient (Mean) [°C]  \
# 2018-12-01 00:00:00                            0.2300
# 2018-12-01 01:00:00                            0.0675
# 2018-12-01 02:00:00                            0.1350
#
#                      Temperature: Module (Mean) [°C]  \
# 2018-12-01 00:00:00                           0.0900
# 2018-12-01 01:00:00                           0.0575
# 2018-12-01 02:00:00                           0.0700
#
#                      Radiation Power (Tilted) (Mean) [W/m²]  \
# 2018-12-01 00:00:00                                     0.0
# 2018-12-01 01:00:00                                     0.0
# 2018-12-01 02:00:00                                     0.0
#
#                      AC Power (norm) (Mean) [kW/kWp]
# 2018-12-01 00:00:00                              0.0
# 2018-12-01 01:00:00                              0.0
# 2018-12-01 02:00:00                              0.0
# (5089, 11)

# %% [markdown]
# ### target= radiation(only)

# %%
data=data.iloc[:,:10]
data.shape
# Out:
# (5089, 10)

# %%
col=data.columns
fig, axs = plt.subplots(10,1,figsize=(15,15))
plt.subplots_adjust(hspace = 1.5)
for i in range(10):
    axs[i].plot(data.iloc[:,i])
    axs[i].set_title(col[i])
# Out:
# C:\Users\reybet\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:102: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### The data is converted into surperviced learning problem. we want to look the data for a week before to predict the actual week. So it is nedded to look (24*7) hours.
# https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/

# %%
lookback_hours = 24*7
n_features = 10
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df =pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# ## Data Normalization

# %% [markdown]
# ### https://machinelearningmastery.com/how-to-scale-data-for-long-short-term-memory-networks-in-python/

# %%
values = data.values    
scaler = MinMaxScaler()
scaled = scaler.fit_transform(values)

# %% [markdown]
# ## Transform the dataframe in a supervised problem

# %%
reframed=series_to_supervised(scaled,lookback_hours, n_out=1, dropnan=True)
print(reframed.shape)
# Out:
# (4921, 1690)

# %%
reframed.columns
# Out:
# Index(['var1(t-168)', 'var2(t-168)', 'var3(t-168)', 'var4(t-168)',
#        'var5(t-168)', 'var6(t-168)', 'var7(t-168)', 'var8(t-168)',
#        'var9(t-168)', 'var10(t-168)',
#        ...
#        'var1(t)', 'var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)',
#        'var7(t)', 'var8(t)', 'var9(t)', 'var10(t)'],
#       dtype='object', length=1690)

# %% [markdown]
# ## Split into train and test sets

# %% [markdown]
# ### It was choosen 20 weeks to train, that represents 70% of the samples.

# %%
values = reframed.values
weeks=20
hours_day=24
days_week=7
row_split =weeks*hours_day*days_week
train = values[:row_split, :]
test = values[row_split:, :]

# %%
print(train.shape, test.shape)
# Out:
# (3360, 1690) (1561, 1690)

# %% [markdown]
# #### selecting in test 9 weeks

# %%
test=test[:1512,:]

# %% [markdown]
# ## Spliting in X and y.

# %% [markdown]
# ### The fist columns that contains all the (t-i) data are using as input variables of the models, and the last column is the target , Radiation Power.

# %%
split_Xy=lookback_hours * n_features
train_X, train_y = train[:, :split_Xy], train[:,-1]
test_X, test_y = test[:, :split_Xy], test[:, -1]

# %%
print(test_X.shape, train_X.shape, train_y.shape, test_y.shape )
# Out:
# (1512, 1680) (3360, 1680) (3360,) (1512,)

# %% [markdown]
# ## Reshape the train samples.

# %% [markdown]
# ### LSTM requires a 3D input [samples, n_steps, features]. In our case the samples are all the rows of the data, the n_steps is how many data Im looking to predict the actual value, and features is the columns of the data, how many types of variables Is was taken into account.
# https://machinelearningmastery.com/?s=input+LSTM&post_type=post&submit=Search
# https://machinelearningmastery.com/reshape-input-data-long-short-term-memory-networks-keras/
# https://medium.com/@shivajbd/understanding-input-and-output-shape-in-lstm-keras-c501ee95c65e

# %%
train_X = train_X.reshape((train_X.shape[0], lookback_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], lookback_hours, n_features))
print(train_X.shape, test_X.shape)
# Out:
# (3360, 168, 10) (1512, 168, 10)

# %% [markdown]
# # Neural Network

# %% [markdown]
# ## Define the model

# %% [markdown]
# ### LSTM https://medium.com/mlreview/understanding-lstm-and-its-diagrams-37e2f46f1714

# %% [markdown]
# #### depth=1 /
# #### nodes=50 nodes
# #### Dropout=0.2
# #### optimizer=adam
# #### loss= mae

# %% [markdown]
# ### dropout
# https://machinelearningmastery.com/how-to-reduce-overfitting-with-dropout-regularization-in-keras/
# https://machinelearningmastery.com/use-dropout-lstm-networks-time-series-forecasting/

# %% [markdown]
# ### adam
# https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/

# %% [markdown]
# ### loss
# https://machinelearningmastery.com/loss-and-loss-functions-for-training-deep-learning-neural-networks/

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# %% [markdown]
# ## Training

# %% [markdown]
# #### epoch=15
# #### batch size=7
# https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/

# %%
history = model.fit(train_X, train_y, epochs=15, batch_size=7, validation_data=(test_X, test_y))
# Out:
# Train on 3360 samples, validate on 1512 samples
# Epoch 1/15
# 3360/3360 [==============================] - 24s 7ms/step - loss: 0.0667 - val_loss: 0.0765
# Epoch 2/15
# 3360/3360 [==============================] - 29s 9ms/step - loss: 0.0395 - val_loss: 0.0612
# Epoch 3/15
# 3360/3360 [==============================] - 24s 7ms/step - loss: 0.0322 - val_loss: 0.0683
# Epoch 4/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0292 - val_loss: 0.0535
# Epoch 5/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0273 - val_loss: 0.0501
# Epoch 6/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0261 - val_loss: 0.0553
# Epoch 7/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0247 - val_loss: 0.0653
# Epoch 8/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0242 - val_loss: 0.0487
# Epoch 9/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0234 - val_loss: 0.0560
# Epoch 10/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0232 - val_loss: 0.0501
# Epoch 11/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0225 - val_loss: 0.0581
# Epoch 12/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0218 - val_loss: 0.0499
# Epoch 13/15
# 3360/3360 [==============================] - 24s 7ms/step - loss: 0.0208 - val_loss: 0.0599
# Epoch 14/15
# 3360/3360 [==============================] - 24s 7ms/step - loss: 0.0210 - val_loss: 0.0462
# Epoch 15/15
# 3360/3360 [==============================] - 23s 7ms/step - loss: 0.0201 - val_loss: 0.0453

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Comparing loss of train and test

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### plot comparing predicted and test_y data

# %%
plt.figure(figsize=(10, 8))
pred = model.predict(test_X)
test_y=pd.DataFrame(test_y)
pred=pd.DataFrame(pred)
#plt.plot(test_y.iloc[:200,1], label='test')
#plt.plot(pred.iloc[:200,1], label='predicted')
#plt.title("AC Power")
#plt.figure()
plt.plot(test_y.iloc[:200,0])
plt.plot(pred.iloc[:200,0])
plt.title("Radiation")
# Out:
# Text(0.5, 1.0, 'Radiation')

# %% [markdown]
# ## Evaluation Metrics
# https://otexts.com/fpp2/accuracy.html

# %%
test_X=test_X.reshape(test_X.shape[0],test_X.shape[1]*test_X.shape[2])

# %%
# # invert scaling for forecast
add_pred = np.concatenate((pred, test_X[:, :-1]), axis=1)
add_pred.shape
#inv_pred = scaler.inverse_transform(add_pred)
# Out:
# (1512, 1680)

# %%
# invert scaling for forecast
inv_pred = concatenate((pred, test_X[:, -9:]), axis=1)
inv_pred = scaler.inverse_transform(inv_pred)
inv_pred = inv_pred[:,0]
# invert scaling for actual
test_y = np.array(test_y).reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -9:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 26.147
